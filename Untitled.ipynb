# %%
import pandas as pd

# %%
import pandas as pd
import html5lib
import lxml
url = 'https://www.icccricketschedule.com/ipl-2021-sun-risers-hyderabad-srh-full-schedule-time-table/'

# %%
df = pd.read_json (r"C:\Users\dhchaudhary\Documents\purplle.json")

# %%
df.to_csv(r"C:\Users\dhchaudhary\Documents\purplle.csv")

# %%
df1 = pd.read_csv(r"C:\Users\dhchaudhary\Documents\purplle.csv")

# %%
df1.head(10)
# Out:
#    Unnamed: 0  event_date   event_timestamp  \
# 0           0    20210428  1619582894968000
# 1           1    20210428  1619596637115002
# 2           2    20210428  1619603185972004
# 3           3    20210428  1619624785453003
# 4           4    20210428  1619606624676003
# 5           5    20210428  1619592376105002
# 6           6    20210428  1619617348733000
# 7           7    20210428  1619627247730000
# 8           8    20210428  1619624785454004
# 9           9    20210428  1619610545200001
#
#                                event_name  \
# 0                              app_update
# 1             REPEAT_FRESH_INSTALL_IN_APP
# 2                                   error
# 3  IN_APP_MESSAGE_FRESH_INSTALL_DISMISSED
# 4                          PROFILE_UPDATE
# 5                NOTIFICATION_NOT_ALLOWED
# 6                      ecommerce_purchase
# 7                              APP_UPDATE
# 8      firebase_in_app_message_impression
# 9                    first_open_consented
#
# ...

# %%
https://merkleinc-my.sharepoint.com/:x:/p/dhchaudhary/EQiQpWe1C55Kp3Wu-hioeWUBRPTFgw1lVSXAezLqBoAHKA?email=karan.sinha%40sokrati.com&e=2d7UMh

# %%
df.event_params.loc[1]
# Out:
# [{'key': 'engaged_session_event',
#   'value': {'string_value': None,
#    'int_value': '1',
#    'float_value': None,
#    'double_value': None}},
#  {'key': 'firebase_event_origin',
#   'value': {'string_value': 'app',
#    'int_value': None,
#    'float_value': None,
#    'double_value': None}},
#  {'key': 'ga_session_id',
#   'value': {'string_value': None,
#    'int_value': '1619596635',
#    'float_value': None,
#    'double_value': None}},
#  {'key': 'firebase_screen_id',
#   'value': {'string_value': None,
#    'int_value': '-6682101267037579359',
#    'float_value': None,
#    'double_value': None}},
#  {'key': 'firebase_screen_class',
#   'value': {'string_value': 'ShopHomeViewController',
#    'int_value': None,
#    'float_value': None,
#    'double_value': None}},
#  {'key': 'device_id',
#   'value': {'string_value': '91C87FED-14BE-499F-8FC6-A1F7E0F9CC61',
#    'int_value': None,
#    'float_value': None,
#    'double_value': None}},
#  {'key': 'ga_session_number',
# ...

# %%
df = pd.read_csv(r"C:\Users\dhchaudhary\Documents\purple.csv")

# %%
df.head(10)
# Out:
#   Unnamed: 0  Unnamed: 1       Unnamed: 2             Unnamed: 3  \
# 0        Row  event_date  event_timestamp             event_name
# 1          1    20210428      1.61958E+15  Silent_Trigger_Push_1
# 2        NaN         NaN              NaN                    NaN
# 3        NaN         NaN              NaN                    NaN
# 4          2    20210428      1.61959E+15        user_engagement
# 5        NaN         NaN              NaN                    NaN
# 6        NaN         NaN              NaN                    NaN
# 7        NaN         NaN              NaN                    NaN
# 8        NaN         NaN              NaN                    NaN
# 9        NaN         NaN              NaN                    NaN
#
#               Unnamed: 4                       Unnamed: 5  \
# 0       event_params.key  event_params.value.string_value
# 1  firebase_event_origin                              app
# 2             event_name            Silent_Trigger_Push_1
# ...

# %%
df.loc[0].to_list()
# Out:
# ['Row',
#  'event_date',
#  'event_timestamp',
#  'event_name',
#  'event_params.key',
#  'event_params.value.string_value',
#  'event_params.value.int_value',
#  'event_params.value.float_value',
#  'event_params.value.double_value',
#  'event_previous_timestamp',
#  'event_value_in_usd',
#  'event_bundle_sequence_id',
#  'event_server_timestamp_offset',
#  'user_id',
#  'user_pseudo_id',
#  'user_properties.key',
#  'user_properties.value.string_value',
#  'user_properties.value.int_value',
#  'user_properties.value.float_value',
#  'user_properties.value.double_value',
#  'user_properties.value.set_timestamp_micros',
#  'user_first_touch_timestamp',
#  'user_ltv.revenue',
#  'user_ltv.currency',
#  'device.category',
#  'device.mobile_brand_name',
#  'device.mobile_model_name',
#  'device.mobile_marketing_name',
#  'device.mobile_os_hardware_model',
#  'device.operating_system',
#  'device.operating_system_version',
#  'device.vendor_id',
#  'device.advertising_id',
# ...

# %%
df.columns.to_list()
# Out:
# ['Unnamed: 0',
#  'Unnamed: 1',
#  'Unnamed: 2',
#  'Unnamed: 3',
#  'Unnamed: 4',
#  'Unnamed: 5',
#  'Unnamed: 6',
#  'Unnamed: 7',
#  'Unnamed: 8',
#  'Unnamed: 9',
#  'Unnamed: 10',
#  'Unnamed: 11',
#  'Unnamed: 12',
#  'Unnamed: 13',
#  'Unnamed: 14',
#  'Unnamed: 15',
#  'Unnamed: 16',
#  'Unnamed: 17',
#  'Unnamed: 18',
#  'Unnamed: 19',
#  'Unnamed: 20',
#  'Unnamed: 21',
#  'Unnamed: 22',
#  'Unnamed: 23',
#  'Unnamed: 24',
#  'Unnamed: 25',
#  'Unnamed: 26',
#  'Unnamed: 27',
#  'Unnamed: 28',
#  'Unnamed: 29',
#  'Unnamed: 30',
#  'Unnamed: 31',
#  'Unnamed: 32',
#  'Unnamed: 33',
#  'Unnamed: 34',
#  'Unnamed: 35',
#  'Unnamed: 36',
#  'Unnamed: 37',
#  'Unnamed: 38',
#  'Unnamed: 39',
#  'Unnamed: 40',
#  'Unnamed: 41',
#  'Unnamed: 42',
#  'Unnamed: 43',
#  'Unnamed: 44',
#  'Unnamed: 45',
#  'Unnamed: 46',
#  'Unnamed: 47',
#  'Unnamed: 48',
#  'Unnamed: 49',
#  'Unnamed: 50',
#  'Unnamed: 51',
#  'Unnamed: 52',
#  'Unnamed: 53',
#  'Unnamed: 54',
#  'Unnamed: 55',
# ...

# %%
df1 = pd.read_csv(r"C:\Users\dhchaudhary\Documents\purple_new.csv")
df1.head()
# Out:
#    Row  event_date  event_timestamp   event_name  event_previous_timestamp  \
# 0    1    20210422     1.619080e+15  screen_view              1.619080e+15
# 1    2    20210422     1.619080e+15  screen_view              1.619080e+15
# 2    3    20210422     1.619080e+15  screen_view              1.619080e+15
#
#    event_bundle_sequence_id  event_server_timestamp_offset  user_id  \
# 0                       NaN                         444386      NaN
# 1                       NaN                        1117810      NaN
# 2                       NaN                        1117810      NaN
#
#                      user_pseudo_id  user_first_touch_timestamp  ...  \
# 0  cf8b58fcacbb8ea51523f094e28138b5                1.616740e+15  ...
# 1  cf8b58fcacbb8ea51523f094e28138b5                1.616740e+15  ...
# 2  cf8b58fcacbb8ea51523f094e28138b5                1.616740e+15  ...
#
#    purchase_revenue  refund_value_in_usd refund_value shipping_value_in_usd  \
# ...

# %%
df1.shape
# Out:
# (3, 52)

# %%
df1.columns.to_list()
# Out:
# ['Row',
#  'event_date',
#  'event_timestamp',
#  'event_name',
#  'event_previous_timestamp',
#  'event_bundle_sequence_id',
#  'event_server_timestamp_offset',
#  'user_id',
#  'user_pseudo_id',
#  'user_first_touch_timestamp',
#  'revenue',
#  'currency',
#  'category',
#  'mobile_brand_name',
#  'mobile_model_name',
#  'mobile_marketing_name',
#  'mobile_os_hardware_model',
#  'operating_system',
#  'vendor_id',
#  'advertising_id',
#  'language',
#  'is_limited_ad_tracking',
#  'time_zone_offset_seconds',
#  'browser',
#  'continent',
#  'country',
#  'region',
#  'city',
#  'sub_continent',
#  'metro',
#  'id',
#  'version',
#  'install_store',
#  'firebase_app_id',
#  'install_source',
#  'name',
#  'medium',
#  'source',
#  'stream_id',
#  'platform',
#  'total_item_quantity',
#  'purchase_revenue_in_usd',
#  'purchase_revenue',
#  'refund_value_in_usd',
#  'refund_value',
#  'shipping_value_in_usd',
#  'shipping_value',
#  'tax_value_in_usd',
#  'tax_value',
# ...

# %%
df_list = pd.read_html(url)

# %%
print(df_list)
# Out:
# [    Match.No                                       Match Center  \
# 0          3       SUNRISERS HYDERABAD Vs KOLKATA KNIGHT RIDERS
# 1          6  SUNRISERS HYDERABAD Vs ROYAL CHALLENGERS BANGA...
# 2          9              MUMBAI INDIANS Vs SUNRISERS HYDERABAD
# 3         14                PUNJAB KINGS Vs SUNRISERS HYDERABAD
# 4         20              SUNRISERS HYDERABAD Vs DELHI CAPITALS
# 5         23         CHENNAI SUPER KINGS Vs SUNRISERS HYDERABAD
# 6         28            RAJASTHAN ROYALS Vs SUNRISERS HYDERABAD
# 7         31              SUNRISERS HYDERABAD Vs MUMBAI INDIANS
# 8         34         SUNRISERS HYDERABAD Vs CHENNAI SUPER KINGS
# 9         38  ROYAL CHALLENGERS BANGALORE Vs SUNRISERS HYDER...
# 10        43             SUNRIERS HYDERABAD Vs RAJASTHAN ROYALS
# 11        48              DELHI CAPITALS Vs SUNRISERS HYDERABAD
# 12        50                SUNRISERS HYDERABAD Vs PUNJAB KINGS
# 13        52       KOLKATA KNIGHT RIDERS Vs SUNRISERS HYDERABAD
#
# ...

# %%
# !pip install html5lib

# %%
df_list[0]
# Out:
#     Match.No                                       Match Center  \
# 0          3       SUNRISERS HYDERABAD Vs KOLKATA KNIGHT RIDERS
# 1          6  SUNRISERS HYDERABAD Vs ROYAL CHALLENGERS BANGA...
# 2          9              MUMBAI INDIANS Vs SUNRISERS HYDERABAD
# 3         14                PUNJAB KINGS Vs SUNRISERS HYDERABAD
# 4         20              SUNRISERS HYDERABAD Vs DELHI CAPITALS
# 5         23         CHENNAI SUPER KINGS Vs SUNRISERS HYDERABAD
# 6         28            RAJASTHAN ROYALS Vs SUNRISERS HYDERABAD
# 7         31              SUNRISERS HYDERABAD Vs MUMBAI INDIANS
# 8         34         SUNRISERS HYDERABAD Vs CHENNAI SUPER KINGS
# 9         38  ROYAL CHALLENGERS BANGALORE Vs SUNRISERS HYDER...
# 10        43             SUNRIERS HYDERABAD Vs RAJASTHAN ROYALS
# 11        48              DELHI CAPITALS Vs SUNRISERS HYDERABAD
# 12        50                SUNRISERS HYDERABAD Vs PUNJAB KINGS
# 13        52       KOLKATA KNIGHT RIDERS Vs SUNRISERS HYDERABAD
#
# ...

# %%
df = pd.DataFrame(data = df_list[0])

# %%
# df = df.iloc[:, :]

# %%
df.to_csv(r"C:\Users\dhchaudhary\Desktop\IPL-2021-Dashboard\schedule\srh_schedule.csv")

# %%
import requests
points_table_data_url = 'https://www.iplt20.com/points-table/men/2021'
html = requests.get(points_table_data_url).content
df_list_points_table = pd.read_html(html)
df_points_table = df_list_points_table[-1]

# %%
df_points_table
# Out:
#    Unnamed: 0                              Team  Pld  Won  Lost  Tied  N/R  \
# 0           1  Royal Challengers Bangalore  RCB    2    2     0     0    0
# 1           2                Mumbai Indians  MI    2    1     1     0    0
# 2           3                Punjab Kings  PBKS    1    1     0     0    0
# 3           4                Delhi Capitals  DC    2    1     1     0    0
# 4           5              Rajasthan Royals  RR    2    1     1     0    0
# 5           6        Kolkata Knight Riders  KKR    2    1     1     0    0
# 6           7          Sunrisers Hyderabad  SRH    2    0     2     0    0
# 7           8          Chennai Super Kings  CSK    1    0     1     0    0
#
#    Net RR       For   Against  Pts  Form
# 0   0.175    309/40    302/40    4  W  W
# 1   0.225    311/40    302/40    2  L  W
# 2   0.200    221/20    217/20    2     W
# 3   0.195  337/38.4  338/39.4    2  W  L
# 4   0.052  367/39.4    368/40    2  L  W
# 5   0.000    329/40    329/40    2  W  L
# ...

# %%
image = pd.read_csv(r"C:\Users\dhchaudhary\Desktop\IPL-2021-Dashboard\schedule\ipl_schedule.csv")

# %%
# !pip install beautifulsoup4

# %%
import bs4
print(bs4.__version__)
# Out:
# 4.9.3

# %%
import requests
from bs4 import BeautifulSoup
URL = 'https://www.iplt20.com/'

# %%
page = requests.get(URL)
from bs4 import BeautifulSoup
job_elems = soup.find_all('section', class_='homePageTakeover')
for job_elem in job_elems:
    title_elem = job_elem.find('h1', class_='hpto-header__title')
    match_summary = job_elem.find('div', class_='matchSummary')
    score = job_elem.find('li', class_='homePageTakeover__button homePageTakeover__button--data-only')
    score_box = job_elem.find('a', href_='https://www.iplt20.com/match/2021/09?tab=scorecard')
    if None in (title_elem, match_summary, score_box):
        continue
    split = title_elem.text.split()
#     print(title_elem.text.strip())
    print("Venue: ", ' '.join(split))
    print('\n')
    print("     ", match_summary.text.strip())
#     print('\n')

#     if (score.text == '\n\n                    Scorecard\n                \n'):
#         print("      Match not Started Yet")
#     else:
    print(score.text.strip())
#       else:
    print(score_box.text.strip())
#     print(countdown.text.strip())
#     print(time.text.strip())
#     print(score.text.strip())
#     score = string(score)
# Out:
#   File "<ipython-input-268-ceb6900f28d9>", line 8
#     score_box = job_elem.find('a', href_=https://www.iplt20.com/match/2021/09?tab=scorecard)
#                                               ^
# SyntaxError: invalid syntax

# %%
import requests
from bs4 import BeautifulSoup
URL = 'https://www.cricbuzz.com/cricket-match/live-scores'

# %%
page = requests.get(URL)
from bs4 import BeautifulSoup

# %%
# !pip install Cython

# %%
page.content
# Out:
# b'\r\n\r\n<!DOCTYPE html><html lang="en" itemscope itemtype="http://schema.org/WebPage"><head><meta charset="utf-8"><script>var is_mobile = /symbian|tizen|midp|uc(web|browser)|MSIE (5.0|6.0|7.0|8.0)|tablet/i.test(navigator.userAgent);\tif(is_mobile && window.location.hostname != "www1.cricbuzz.com") window.location.hostname = "m.cricbuzz.com";</script><style>body{background:#E3E6E3; font-family: helvetica,"Segoe UI",Arial,sans-serif;color:#222;font-size:14px; line-height: 1.5; margin:0;}\tbody, .cb-comm-pg, .cb-hm-mid {min-height:1000px}\t.container{width:980px;margin:0 auto;}\t.page{max-width: 980px;margin: 0 auto;position: relative;}\t.cb-col-8 {width:8%;}\t.cb-col-10 {width:10%;}\t.cb-col-14 {width:14%;}\t.cb-col-16 {width:16%;}\t.cb-col-20 {width:20%;}\t.cb-col-25 {width:25%;}\t.cb-col-27 {width:27%;}\t.cb-col-33 {width:33%;}\t.cb-col-40 {width:40%;}\t.cb-col-46 {width:46%;}\t.cb-col-47 {width:47%;}\t.cb-col-50 {width:50%;}\t.cb-col-60 {width:60%;}\t.cb-col-66 {width:66%;}\t.cb-c
# ...

# %%
# pprint(page.content)

# %%
x

# %%
# results = soup.find(id = )

# %%
# print(job_elems)

# %%
# import os
# print(title_elem.text.replace('\n', '').replace('\r', ''))

# %%
# import os
# split = title_elem.text.splitlines()

# %%
# split

# %%
# print(' '.join(split[1:3]))
